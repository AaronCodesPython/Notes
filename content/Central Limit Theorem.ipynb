# %% [markdown]
# ## Central Limit Theorem
# -> basic statement: The central limit theorem states that if you take sufficiently large samples from a population, the samples' means will be normally distributed, even if the population isn't normally distributed
# ### example

# %%
import numpy as np
import matplotlib.pyplot as plt

N=100
population_happiness_score = np.random.randint(5, size=(N, N))
flat = population_happiness_score.flatten()      
print(flat)
averages = np.zeros(N)
for i in range(0,N):
    
    for j in range(0,N):
        averages[i]+= population_happiness_score[i][j]
        
    averages[i] /= N
plt.hist(flat, bins = 5, density = True)
plt.show()
# Out:
# [4 4 3 ... 2 3 4]

# %%
plt.hist(averages, bins=50, density=True)
plt.title("Distribution of sample means")
plt.xlabel("Average happiness score")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ## Why does this happen?
# I recommend reading some of the answers here: https://stats.stackexchange.com/questions/3734/what-intuitive-explanation-is-there-for-the-central-limit-theorem
#
# It is important to note that the Central limit theorem in it's general form only applies to addition, for other operations similar theorems exist but they are less general.
